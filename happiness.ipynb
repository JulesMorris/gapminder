# %%
import pandas as pd

# %%
whr_2015 = pd.read_csv('whr_2015.csv')
whr_2016 = pd.read_csv('whr_2016.csv')
whr_2017 = pd.read_csv('whr_2017.csv')
whr_2018 = pd.read_csv('whr_2018.csv')
whr_2019 = pd.read_csv('whr_2019.csv')
whr_2020 = pd.read_csv('whr_2020.csv')
whr_2021 = pd.read_csv('whr_2021.csv')
#whr_2022 = pd.read_csv('whr_2022.csv')

# %%
whr_2015['year'] = 2015
whr_2016['year'] = 2016
whr_2017['year'] = 2017
whr_2018['year'] = 2018
whr_2019['year'] = 2019
whr_2020['year'] = 2020
whr_2021['year'] = 2021

# %%
whr_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
whr_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
whr_2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
whr_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
whr_2020.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
print('2015: ', whr_2015.Country.nunique())
print('2016: ', whr_2016.Country.nunique())
print('2017: ', whr_2017.Country.nunique())
print('2018: ', whr_2018['Country or region'].nunique())
print('2019: ', whr_2019['Country or region'].nunique())
print('2020: ', whr_2020['Country name'].nunique())
print('2021: ', whr_2021['Country name'].nunique())
# Out:
# 2015:  158
# 2016:  157
# 2017:  155
# 2018:  156
# 2019:  156
# 2020:  153
# 2021:  149

# %%
#use this df to add region column later for years where region is missing
get_regions = whr_2015.copy()

get_regions = get_regions[['Country', 'Region']]
get_regions = pd.DataFrame(get_regions)
get_regions.head()
# Out:
#        Country          Region
# 0  Switzerland  Western Europe
# 1      Iceland  Western Europe
# 2      Denmark  Western Europe
# 3       Norway  Western Europe
# 4       Canada   North America

# %%
#add region
whr_2017 = pd.merge(whr_2017, get_regions, how = 'left', on = 'Country')

# %%
#add region
whr_2018 = whr_2018.rename(columns = {'Country or region': 'Country'})
whr_2018 = pd.merge(whr_2018, get_regions, how = 'left', on = 'Country')

# %%
#add region
whr_2019 = whr_2019.rename(columns = {'Country or region': 'Country'})
whr_2019 = pd.merge(whr_2019, get_regions, how = 'left', on = 'Country')

# %%
whr_2019.head()
# Out:
#    Overall rank      Country  Score  GDP per capita  Social support  \
# 0             1      Finland  7.769           1.340           1.587
# 1             2      Denmark  7.600           1.383           1.573
# 2             3       Norway  7.554           1.488           1.582
# 3             4      Iceland  7.494           1.380           1.624
# 4             5  Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption          Region
# 0                      0.393  Western Europe
# 1                      0.410  Western Europe
# ...

# %%
w = whr_2018.copy()
w.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
w = w.rename(columns = {'Country or region': 'Country'})
w.head()
# Out:
#    Overall rank      Country  Score  GDP per capita  Social support  \
# 0             1      Finland  7.632           1.305           1.592
# 1             2       Norway  7.594           1.456           1.582
# 2             3      Denmark  7.555           1.351           1.590
# 3             4      Iceland  7.495           1.343           1.644
# 4             5  Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# 2                      0.408
# ...

# %%
w = pd.merge(w, get_regions, how = 'left', on = 'Country')
# Out:
#     Overall rank               Country  Score  GDP per capita  Social support  \
# 0              1               Finland  7.632           1.305           1.592
# 1              2                Norway  7.594           1.456           1.582
# 2              3               Denmark  7.555           1.351           1.590
# 3              4               Iceland  7.495           1.343           1.644
# 4              5           Switzerland  7.487           1.420           1.549
# 5              6           Netherlands  7.441           1.361           1.488
# 6              7                Canada  7.328           1.330           1.532
# 7              8           New Zealand  7.324           1.268           1.601
# 8              9                Sweden  7.314           1.355           1.501
# 9             10             Australia  7.272           1.340           1.573
# 10            11        United Kingdom  7.190           1.244           1.433
# ...

# %%
whr_2015.columns

# %%
whr_2015.drop(columns = ['Standard Error', 'Dystopia Residual'], inplace = True)

# %%
whr_2016.columns

# %%
whr_2016.drop(columns = ['Lower Confidence Interval', 'Upper Confidence Interval', 'Dystopia Residual'], inplace = True)

# %%
whr_2016.shape

# %%
whr_2017.columns

# %%
whr_2017.drop(columns = ['Whisker.high', 'Whisker.low', 'Dystopia.Residual'], inplace = True)

# %%
whr_2017.shape #will need to add region

# %%
whr_2017.head()

# %%
whr_2018.columns

# %%
whr_2019.columns

# %%
whr_2020.columns

# %%
whr_2020.shape

# %%
whr_2020.head()

# %%
whr_2020.drop(columns = ['Standard error of ladder score', 
                         'upperwhisker', 
                         'lowerwhisker',
                         'Ladder score in Dystopia',
                         'Explained by: Log GDP per capita',
                         'Explained by: Social support',
                         'Explained by: Healthy life expectancy',
                         'Explained by: Freedom to make life choices',
                         'Explained by: Generosity',
                         'Explained by: Perceptions of corruption',
                         'Dystopia + residual'
                        ], inplace = True)

# %% [markdown]
# df['Auction_Rank'] = df.groupby('Auction_ID')['Bid_Price'].rank(ascending=False)

# %% [markdown]
# #creating a rank column and passing the returned rank series for all unique values
# data["Rank"] = data["Name"].rank()

# %%
whr

# %%
#create rank column

whr_2020['happiness_rank'] = whr_2020['Ladder score'].rank(ascending = False)
whr_2020.head()
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe        7.8087              10.639267
# 1      Denmark     Western Europe        7.6456              10.774001
# 2  Switzerland     Western Europe        7.5599              10.979933
# 3      Iceland     Western Europe        7.5045              10.772559
# 4       Norway     Western Europe        7.4880              11.087804
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0        0.954330                71.900825                      0.949172
# 1        0.955991                72.402504                      0.951444
# 2        0.942847                74.102448                      0.921337
# 3        0.974670                73.000000                      0.948892
# 4        0.952487                73.200783                      0.955750
#
#    Generosity  Perceptions of corruption  year  happiness_rank
# ...

# %%
whr_2021.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
whr_2021.drop(columns = ['Standard error of ladder score', 
                         'upperwhisker', 
                         'lowerwhisker',
                         'Ladder score in Dystopia',
                         'Explained by: Log GDP per capita',
                         'Explained by: Social support',
                         'Explained by: Healthy life expectancy',
                         'Explained by: Freedom to make life choices',
                         'Explained by: Generosity',
                         'Explained by: Perceptions of corruption',
                         'Dystopia + residual'
                        ], inplace = True)

# %%
#create rank column
whr_2021['happiness_rank'] = whr_2021['Ladder score'].rank(ascending = False)

# %%
whr_2017.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Economy..GDP.per.Capita.  \
# 0  Norway               1            7.537                  1.616463
#
#      Family  Health..Life.Expectancy.   Freedom  Generosity  \
# 0  1.533524                  0.796667  0.635423    0.362012
#
#    Trust..Government.Corruption.          Region
# 0                       0.315964  Western Europe

# %%
whr_2018.head()
# Out:
#    Overall rank      Country  Score  GDP per capita  Social support  \
# 0             1      Finland  7.632           1.305           1.592
# 1             2       Norway  7.594           1.456           1.582
# 2             3      Denmark  7.555           1.351           1.590
# 3             4      Iceland  7.495           1.343           1.644
# 4             5  Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption          Region
# 0                      0.393  Western Europe
# 1                      0.340  Western Europe
# ...

# %%
whr_2019.head()
# Out:
#    Overall rank      Country  Score  GDP per capita  Social support  \
# 0             1      Finland  7.769           1.340           1.587
# 1             2      Denmark  7.600           1.383           1.573
# 2             3       Norway  7.554           1.488           1.582
# 3             4      Iceland  7.494           1.380           1.624
# 4             5  Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption          Region
# 0                      0.393  Western Europe
# 1                      0.410  Western Europe
# ...

# %%
whr_2020.head()
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe        7.8087              10.639267
# 1      Denmark     Western Europe        7.6456              10.774001
# 2  Switzerland     Western Europe        7.5599              10.979933
# 3      Iceland     Western Europe        7.5045              10.772559
# 4       Norway     Western Europe        7.4880              11.087804
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0        0.954330                71.900825                      0.949172
# 1        0.955991                72.402504                      0.951444
# 2        0.942847                74.102448                      0.921337
# 3        0.974670                73.000000                      0.948892
# 4        0.952487                73.200783                      0.955750
#
#    Generosity  Perceptions of corruption  happiness_rank
# ...

# %%
whr_2021.head()
# Out:
#   Country name Regional indicator  Ladder score  Logged GDP per capita  \
# 0      Finland     Western Europe         7.842                 10.775
# 1      Denmark     Western Europe         7.620                 10.933
# 2  Switzerland     Western Europe         7.571                 11.117
# 3      Iceland     Western Europe         7.554                 10.878
# 4  Netherlands     Western Europe         7.464                 10.932
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions of corruption  happiness_rank
# ...

# %%
whr_2021.columns
# Out:
# Index(['Country name', 'Regional indicator', 'happiness_rank', 'Ladder score',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
whr_2015.shape
# Out:
# (158, 10)

# %%
whr_2016.shape
# Out:
# (157, 10)

# %%
whr_2017.shape
# Out:
# (155, 10)

# %%
whr_2018.shape
# Out:
# (156, 10)

# %%
whr_2019.shape
# Out:
# (156, 10)

# %%
whr_2020.shape
# Out:
# (153, 10)

# %%
whr_2021.shape
# Out:
# (149, 10)

# %%
new_column_names =['country', 
                   'region', 
                   'happiness_rank', 
                   'happiness_score', 
                   'gdp_per_cap', 
                   'social_support', 
                   'healthy_life_exp', 
                   'freedom', 
                   'generosity', 
                   'corruption_perception']

# %%
#reorder and rename
whr_2015 =  whr_2015[['Country', 
                      'Region', 
                      'Happiness Rank', 
                      'Happiness Score', 
                      'Economy (GDP per Capita)', 
                      'Family', 
                      'Health (Life Expectancy)', 
                      'Freedom',
                      'Generosity', 
                      'Trust (Government Corruption)',
                     'year']]

whr_2015 = whr_2015.rename(columns = {'Country': 'country', 
                                      'Region':'region', 
                                      'Happiness Rank': 'happiness_rank', 
                                      'Happiness Score':'happiness_score', 
                                      'Economy (GDP per Capita)':'gdp_per_cap', 
                                      'Family':'social_support', 
                                      'Health (Life Expectancy)':'healthy_life_exp', 
                                      'Freedom':'freedom',
                                      'Generosity':'generosity', 
                                      'Trust (Government Corruption)': 'corruption_perception'
                                     })

# %%
#reorder and rename
whr_2016 =  whr_2016[['Country', 
                      'Region', 
                      'Happiness Rank', 
                      'Happiness Score', 
                      'Economy (GDP per Capita)', 
                      'Family', 
                      'Health (Life Expectancy)', 
                      'Freedom',
                      'Generosity', 
                      'Trust (Government Corruption)',
                     'year']]

whr_2016 = whr_2016.rename(columns = {'Country': 'country', 
                                      'Region':'region', 
                                      'Happiness Rank': 'happiness_rank', 
                                      'Happiness Score':'happiness_score', 
                                      'Economy (GDP per Capita)':'gdp_per_cap', 
                                      'Family':'social_support', 
                                      'Health (Life Expectancy)':'healthy_life_exp', 
                                      'Freedom':'freedom',
                                      'Generosity':'generosity', 
                                      'Trust (Government Corruption)': 'corruption_perception'
                                     })

# %%
#reorder and rename
whr_2017 = whr_2017[['Country',
                     'Region', 
                     'Happiness.Rank', 
                     'Happiness.Score', 
                     'Economy..GDP.per.Capita.', 
                     'Family', 
                     'Health..Life.Expectancy.', 
                     'Freedom',
                     'Generosity', 
                     'Trust..Government.Corruption.',
                    'year']]

whr_2017 = whr_2017.rename(columns = {'Country':'country',
                     'Region':'region', 
                     'Happiness.Rank':'happiness_rank', 
                     'Happiness.Score':'happiness_score', 
                     'Economy..GDP.per.Capita.':'gdp_per_cap', 
                     'Family':'social_support', 
                     'Health..Life.Expectancy.':'healthy_life_exp', 
                     'Freedom':'freedom',
                     'Generosity':'generosity', 
                     'Trust..Government.Corruption.':'corruption_perception'})

# %%
whr_2018 = whr_2018[['Country', 
                     'Region', 
                     'Overall rank', 
                     'Score', 
                     'GDP per capita', 
                     'Social support', 
                     'Healthy life expectancy',
                     'Freedom to make life choices', 
                     'Generosity',
                     'Perceptions of corruption',
                    'year']]

whr_2018 = whr_2017.rename(columns = {'Country':'country', 
                     'Region':'region', 
                     'Overall rank':'happiness_rank', 
                     'Score':'happiness_score', 
                     'GDP per capita':'gdp_per_cap', 
                     'Social support':'social_support', 
                     'Healthy life expectancy':'healthy_life_exp',
                     'Freedom to make life choices':'freedom', 
                     'Generosity':'generosity',
                     'Perceptions of corruption':'corruption_perception'
    
})

# %%
whr_2019 = whr_2019[['Country', 
                     'Region', 
                     'Overall rank', 
                     'Score', 
                     'GDP per capita', 
                     'Social support', 
                     'Healthy life expectancy',
                     'Freedom to make life choices', 
                     'Generosity',
                     'Perceptions of corruption',
                    'year']]

whr_2019 = whr_2019.rename(columns = {'Country':'country', 
                     'Region':'region', 
                     'Overall rank':'happiness_rank', 
                     'Score':'happiness_score', 
                     'GDP per capita':'gdp_per_cap', 
                     'Social support':'social_support', 
                     'Healthy life expectancy':'healthy_life_exp',
                     'Freedom to make life choices':'freedom', 
                     'Generosity':'generosity',
                     'Perceptions of corruption':'corruption_perception'
    
})

# %%
whr_2020 = whr_2020[['Country name', 
                     'Regional indicator', 
                     'happiness_rank', 
                     'Ladder score', 
                     'Logged GDP per capita', 
                     'Social support', 
                     'Healthy life expectancy', 
                     'Freedom to make life choices', 
                     'Generosity', 
                     'Perceptions of corruption',
                    'year']]

whr_2020 = whr_2020.rename(columns = {'Country name':'country', 
                     'Regional indicator':'region', 
                     'happiness_rank':'happiness_rank', 
                     'Ladder score':'happiness_score', 
                     'Logged GDP per capita':'gdp_per_cap', 
                     'Social support':'social_support', 
                     'Healthy life expectancy':'healthy_life_exp', 
                     'Freedom to make life choices':'freedom', 
                     'Generosity':'generosity', 
                     'Perceptions of corruption':'corruption_perception'
    
})

# %%
whr_2021 = whr_2021[['Country name', 
                     'Regional indicator', 
                     'happiness_rank', 
                     'Ladder score', 
                     'Logged GDP per capita', 
                     'Social support', 
                     'Healthy life expectancy', 
                     'Freedom to make life choices', 
                     'Generosity', 
                     'Perceptions of corruption',
                    'year']]

whr_2021 = whr_2021.rename(columns = {'Country name':'country', 
                     'Regional indicator':'region', 
                     'happiness_rank':'happiness_rank', 
                     'Ladder score':'happiness_score', 
                     'Logged GDP per capita':'gdp_per_cap', 
                     'Social support':'social_support', 
                     'Healthy life expectancy':'healthy_life_exp', 
                     'Freedom to make life choices':'freedom', 
                     'Generosity':'generosity', 
                     'Perceptions of corruption':'corruption_perception'
    
})

# %%
#fix order
# whr_2015 = whr_2015[['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom','Generosity', 'Trust (Government Corruption)']]
# whr_2016 = whr_2016[['Country', 'Region', 'Happiness Rank', 'Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom','Generosity', 'Trust (Government Corruption)']]
# whr_2017 = whr_2017[['Country','Region', 'Happiness.Rank', 'Happiness.Score', 'Economy..GDP.per.Capita.', 'Family', 'Health..Life.Expectancy.', 'Freedom','Generosity', 'Trust..Government.Corruption.']]
# whr_2018 = whr_2018[['Country', 'Region', 'Overall rank', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices', 'Generosity','Perceptions of corruption']]
# whr_2019 = whr_2019[['Country','Region', 'Overall rank', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices', 'Generosity','Perceptions of corruption']]
# whr_2020 = whr_2020[['Country name', 'Regional indicator', 'happiness_rank', 'Ladder score', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]
# whr_2021 = whr_2021[['Country name', 'Regional indicator', 'happiness_rank', 'Ladder score', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]

# new_column_names =['country', 
#                    'region', 
#                    'happiness_rank', 
#                    'happiness_score', 
#                    'gdp_per_cap', 
#                    'social_support', 
#                    'healthy_life_exp', 
#                    'autonomy', 
#                    'generosity', 
#                    'corruption_perception']


# years = [whr_2015, whr_2016, whr_2017, whr_2018, whr_2019, whr_2020, whr_2021]
# for year in years:
#     year.columns = new_column_names

# %%
whr_total = [whr_2015, whr_2016, whr_2017, whr_2018, whr_2019, whr_2020, whr_2021]

whr = pd.concat(whr_total)
whr.head(100)
# Out:
#                    country                       region  happiness_rank  \
# 0              Switzerland               Western Europe             1.0
# 1                  Iceland               Western Europe             2.0
# 2                  Denmark               Western Europe             3.0
# 3                   Norway               Western Europe             4.0
# 4                   Canada                North America             5.0
# ..                     ...                          ...             ...
# 95  Bosnia and Herzegovina   Central and Eastern Europe            96.0
# 96                 Lesotho           Sub-Saharan Africa            97.0
# 97      Dominican Republic  Latin America and Caribbean            98.0
# 98                    Laos            Southeastern Asia            99.0
# 99                Mongolia                 Eastern Asia           100.0
#
#     happiness_score  gdp_per_cap  social_support  healthy_life_exp  freedom  \
# ...

# %%
whr.shape
# Out:
# (1083, 11)

# %%
whr.isna().sum()
# Out:
# country                   0
# region                   19
# happiness_rank            0
# happiness_score           0
# gdp_per_cap               0
# social_support            0
# healthy_life_exp          0
# freedom                   0
# generosity                0
# corruption_perception     0
# year                      0
# dtype: int64

# %%
pd.set_option('display.max_rows', None)

whr
# Out:
#                        country                              region  \
# 0                  Switzerland                      Western Europe
# 1                      Iceland                      Western Europe
# 2                      Denmark                      Western Europe
# 3                       Norway                      Western Europe
# 4                       Canada                       North America
# 5                      Finland                      Western Europe
# 6                  Netherlands                      Western Europe
# 7                       Sweden                      Western Europe
# 8                  New Zealand           Australia and New Zealand
# 9                    Australia           Australia and New Zealand
# 10                      Israel     Middle East and Northern Africa
# 11                  Costa Rica         Latin America and Caribbean
# 12                     Austria                      Western Europe
# ...

# %%
38 Trinidad & Tobago Latin America and Caribbean

63 Northern Cyprus -- Western Europe --> North Cyprus
83 North Macedonia -- Central and Eastern Europe
92 Somalia -- 
155 South Sudan -- central africa?

# %%
#target is happiness_score

# %%
#train, test, split
train_validate, test = train_test_split(df, test_size = .2, random_state = 123)
train, validate = train_test_split(train_validate, test_size = .3, random_state = 123)

# %%
#get scaled data


def scale_data(train, 
               validate, 
               test, 
               columns_to_scale = [column_list],
               return_scaler = False):
    '''
    Scales the 3 data splits. 
    Takes in train, validate, and test data splits and returns their scaled counterparts.
    If return_scalar is True, the scaler object will be returned as well
    '''
    train_scaled = train.copy()
    validate_scaled = validate.copy()
    test_scaled = test.copy()
    
    scaler = StandardScaler()
    scaler.fit(train[columns_to_scale])
    
    train_scaled[columns_to_scale] = pd.DataFrame(scaler.transform(train[columns_to_scale]),
                                                  columns = train[columns_to_scale].columns.values).set_index([train.index.values])
                                                  
    validate_scaled[columns_to_scale] = pd.DataFrame(scaler.transform(validate[columns_to_scale]),
                                                  columns = validate[columns_to_scale].columns.values).set_index([validate.index.values])
    
    test_scaled[columns_to_scale] = pd.DataFrame(scaler.transform(test[columns_to_scale]),
                                                 columns = test[columns_to_scale].columns.values).set_index([test.index.values])
    
    if return_scaler:
        return scaler, train_scaled, validate_scaled, test_scaled
    else:
        return train_scaled, validate_scaled, test_scaled

# %%
#acquire data
train, validate, test, df = zc_wrangle.wrangled_zillow()

#acquire split data
train_VC, train_LA, train_OC, validate_VC, validate_LA, validate_OC, test_VC, test_LA, test_OC = zc_wrangle.split_county_tvt(train, validate, test) 

#acquire scaled data
scaler, train_scaled, validate_scaled, test_scaled = zc_wrangle.scale_data(train, validate, test, return_scaler = True)

#acquire scaled split data
scaler, train_scaled_VC, train_scaled_LA, train_scaled_OC, validate_scaled_VC, validate_scaled_LA, validate_scaled_OC, test_scaled_VC, test_scaled_LA, test_scaled_OC = zc_wrangle.scale_split_data(train, validate, test, return_scaler = True)

train.head()
